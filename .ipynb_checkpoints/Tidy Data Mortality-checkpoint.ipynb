# %%
import pandas as pd
import numpy as np
import os

comp_mort = pd.read_csv("./data/comp_mort_99-16.txt",
                       delimiter = '\t',
                       header=0,
                       names=["Notes", "County", "County Code","Infant Age Groups",
                              "Infant Age Groups Code","Deaths","Population","Crude Rate"])
comp_mort
# Out:
#                                                   Notes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# ...
